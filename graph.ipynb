# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ber_list_prs_10db = [0.11222887771122289,
0.08265917340826592,
0.056919430805691944,
0.03577964220357797,
0.020409795902040978,
0.010669893301066989,
0.005109948900510995,
0.001939980600193998,
0.0006099939000609993,
0.00015999840001599985,
5.999940000599994e-05,
0.0,
0.0]

# %%
ber_list_ook_10db = [0.114,
0.0811,
0.05655,
0.03624,
0.02115,
0.01068,
0.00484,
0.00196,
0.00044,
0.0001,
2e-05,
0.0,
0.0]

# %%
ber_list_ook_5db = [0.110635,
0.080747,
0.054943,
0.035356,
0.020933,
0.011132,
0.00535,
0.002278,
0.00088,
0.000253,
7.2e-05,
1.3e-05,
0.0]

# %%
ber_list_ook_5db_27 = [0.133358,
0.102432,
0.075331,
0.053617,
0.035329,
0.022256,
0.012698,
0.00675,
0.003215,
0.001409,
0.000469,
0.00014,
2.8e-05]

# %%
ber_list_ook_10db_36 = [0.120259,
0.089072,
0.0616,
0.04041,
0.024486,
0.013051,
0.006254,
0.002494,
0.000786,
0.000219,
2.6e-05,
7e-06,
1e-06]

# %%
ber_list_1 = ber_list_prs_10db
ber_list_2 = ber_list_ook_10db

# %%
ebn0_range = range(4, 17)
# 绘制BER曲线
plt.figure(figsize=(10, 6))
plt.semilogy(ebn0_range, ber_list_1, 'b-o', linewidth=2, markersize=8,label='Eb/N0 = 10dB,denoised prs')
plt.semilogy(ebn0_range, ber_list_2, 'g-s', linewidth=2, markersize=8,label='Eb/N0 = 10dB,decoded signal')
plt.legend()
plt.xlabel('Eb/N0 (dB)', fontsize=12)
plt.ylabel('Bit Error Rate (BER)', fontsize=12)
plt.title('BER Performance vs Eb/N0', fontsize=14)
plt.grid(True, which="both", ls="--")
plt.xticks(ebn0_range)
plt.ylim(1e-5, 1)  # 根据实际BER调整范围
# Out:
# (1e-05, 1)
